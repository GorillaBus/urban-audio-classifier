# %% [markdown]
# ## Log-Scaled MFCC
# Not really a normalization procedure, but some articles ("A Comparison of Audio Signal Preprocessing Methods for Deep Neural Networks on Music Tagging") state that log-scaling improves accuracy. This is simply done by converting amplitude to a db scale.<br/>
#
# https://stackoverflow.com/questions/55513652/which-spectrogram-best-represents-features-of-an-audio-file-for-cnn-based-model

# %%
import sys
import os
import IPython
import math
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
import random
from datetime import datetime 

from keras import backend as keras_backend, models
from keras.models import Sequential
from keras.layers import Dense, SpatialDropout2D, Activation, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint 

from sklearn import metrics, preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
# Define general variables

# Set your path to the dataset
us8k_path = os.path.abspath('./UrbanSound8K')
audio_path = os.path.join(us8k_path, 'audio')
metadata_path = os.path.join(us8k_path, 'metadata/UrbanSound8K.csv')
data_path = os.path.abspath('./data')
models_path = os.path.abspath('./models')

# Ensure "channel last" data format on Keras
keras_backend.set_image_data_format('channels_last')

# %%
# Load the metadata from the generated CSV
metadata = pd.read_csv(metadata_path)

# %% [markdown]
# #### Helper functions

# %%
# Helper: Generates MFCC coefficients with Librosa 
def get_mfcc(filename, mfcc_max_padding=0):
    try:
        audio, sample_rate = librosa.load(filename, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        # log-scaling 
        mfccs = librosa.core.power_to_db(mfccs)

        # Should we require padding
        pad_width = mfcc_max_padding - mfccs.shape[1]
        if (mfcc_max_padding > 0 & mfccs.shape[1] < mfcc_max_padding):
            pad_width = mfcc_max_padding - mfccs.shape[1]
            mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')

    except Exception as e:
        print("Error parsing wavefile: ", filename)
        return None 
    return mfccs

# %% [markdown]
# #### Load metadata

# %%
# Load the metadata from the generated CSV
metadata = pd.read_csv(metadata_path)

# Examine dataframe
metadata.head()

# %% [markdown]
# #### Full dataset MFCC extraction

# %%
# Iterate through all audio files and extract MFCC
features = []
labels = []
frames_max = 0
counter = 0
total_samples = len(metadata)

for index, row in metadata.iterrows():
    file_name = os.path.join(os.path.abspath(audio_path), 'fold' + str(row["fold"]), str(row["slice_file_name"]))
    class_label = row["class"]
    mfccs = get_mfcc(file_name)    
    num_frames = mfccs.shape[1]
    
    # Per-channel normalization
    mean = np.mean(mfccs, axis=1, keepdims=True)
    std = np.std(mfccs, axis=1, keepdims=True)
    mfccs = (mfccs - mean) / std

    
    # Add row (feature / label)
    features.append(mfccs)
    labels.append(class_label)

    # Update frames maximum
    if (num_frames > frames_max):
        frames_max = num_frames

    # Notify update every N files
    if (counter == 500):
        print("Status: {}/{}".format(index+1, total_samples))
        counter = 0
    
    counter += 1
    
print("Finished: {}/{}".format(index, total_samples))

# %% [markdown]
# #### Add padding for a consistent shape

# %%
padded = []

# Add padding
mfcc_max_padding = frames_max
for i in range(len(features)):
    size = len(features[i][0])
    if (size < mfcc_max_padding):
        pad_width = mfcc_max_padding - size
        px = np.pad(features[i], 
                    pad_width=((0, 0), (0, pad_width)), 
                    mode='constant', 
                    constant_values=(0,))
    
    padded.append(px)

# %% [markdown]
# #### Save X and y

# %%
# Convert features (X) and labels (y) to Numpy arrays

X = np.array(padded)
y = np.array(labels)

# Optionally save the features to disk
np.save("data/X-v5", X)
np.save("data/y-v5", y)

# %%
# Verify shapes
print("Raw features length: {}".format(len(features)))
print("Padded features length: {}".format(len(padded)))
print("Feature labels length: {}".format(len(features)))
print("X: {}, y: {}".format(X.shape, y.shape))

# %% [markdown]
# ### Helper functions

# %%
# Helper: Generates MFCC coefficients with Librosa 
def get_mfcc(filename, mfcc_max_padding=0):
    try:
        audio, sample_rate = librosa.load(filename, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
                
        # Should we require padding?
        pad_width = mfcc_max_padding - mfccs.shape[1]
        if (mfcc_max_padding > 0 & mfccs.shape[1] < mfcc_max_padding):
            pad_width = mfcc_max_padding - mfccs.shape[1]
            mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')

    except Exception as e:
        print("Error parsing wavefile: ", filename)
        return None 
    return mfccs

# Given a file returns a list of prediction results
def predict_from_file(file_name, num_rows, num_columns, num_channels):
    # Note we use num_columns as our padding value!
    feature = get_mfcc(file_name, mfcc_max_padding=num_columns) 
    feature = feature.reshape(1, num_rows, num_columns, num_channels)
    predicted_vector = model.predict_classes(feature)
    predicted_class = le.inverse_transform(predicted_vector)
    predicted_proba = model.predict_proba(feature)[0]
    return [
        predicted_class,
        predicted_proba
    ]

# Reads the defaul directory for extra evaluation files and returns a pandas dataframe
def get_external_samples(base_path):
    files = []
    labels = []

    # Iterate category directories
    dirs = os.listdir(base_path)
    for d in dirs:
        category = d
        category_path = os.path.join(base_path, d)

        # Iterate files
        dir_files = os.listdir(category_path)

        for file in dir_files:
            file_path = os.path.join(category_path, file)
            files.append(file_path)
            labels.append(category)

    # Create dataframe
    return pd.DataFrame({ 'class': labels, 'file': files })
    
    
def plot_confusion_matrix(y_true, 
                          y_pred, 
                          classes, 
                          normalize=False, 
                          title=None, 
                          cmap=plt.cm.Blues,
                          size=(10,10)):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = metrics.confusion_matrix(y_true, y_pred)
        
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    fig, ax = plt.subplots(figsize=size)
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)

    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")

    fig.tight_layout()
    return [cm, ax]



# Expects a NumPy array with probabilities, retuns accuracy per class
def acc_per_class(np_probs_array):
    accs = []
    for idx in range(0, np_probs_array.shape[0]):
        correct = cm[idx][idx].astype(int)
        total = cm[idx].sum().astype(int)
        acc = (correct / total) * 100
        accs.append(acc)
    return accs

# %% [markdown]
# ### Load data (v5)

# %%
# Pre-processed MFCC coefficients and labels & metadata

X = np.load("data/X-v5.npy")
y = np.load("data/y-v5.npy")

# %% [markdown]
# ### Data preparation: features + metadata

# %% [markdown]
# #### Train / Test split

# %%
indexes = []
total = len(metadata)
indexes = list(range(0, total))

# Randomize indexes
random.shuffle(indexes)

# Divide the indexes into Train and Test
test_split_pct = 20
split_offset = math.floor(test_split_pct * total / 100)

# Split the metadata
test_split_idx = indexes[0:split_offset]
train_split_idx = indexes[split_offset:total]
test_meta = metadata.iloc[test_split_idx]
train_meta = metadata.iloc[train_split_idx]

# Split the features the with the same indexes
X_test = np.take(X, test_split_idx, axis=0)
y_test = np.take(y, test_split_idx, axis=0)
X_train = np.take(X, train_split_idx, axis=0)
y_train = np.take(y, train_split_idx, axis=0)

# Print status
print("Test split: {} \t\t Train split: {}".format(len(test_meta), len(train_meta)))
print("X test shape: {} \t X train shape: {}".format(X_test.shape, X_train.shape))
print("y test shape: {} \t\t y train shape: {}".format(y_test.shape, y_train.shape))
# Out:
# Test split: 1746 		 Train split: 6986
# X test shape: (1746, 40, 174) 	 X train shape: (6986, 40, 174)
# y test shape: (1746,) 		 y train shape: (6986,)

# %% [markdown]
# #### One hot encode labels

# %%
le = LabelEncoder()
y_test_encoded = to_categorical(le.fit_transform(y_test))
y_train_encoded = to_categorical(le.fit_transform(y_train))

# %% [markdown]
# #### Reshape data

# %%
# How data should be organized
num_rows = 40
num_columns = 174 # Remember how we padded the data in the previous notebook?
num_channels = 1

# Reshape to fit the network input (channel last!)
X_train = X_train.reshape(X_train.shape[0], num_rows, num_columns, num_channels)
X_test = X_test.reshape(X_test.shape[0], num_rows, num_columns, num_channels)

# Total number of labels to predict (equal to the network output nodes)
num_labels = y_train_encoded.shape[1]

# %% [markdown]
# ### Model definition

# %%
model = Sequential()

# Input shape
input_shape = (num_rows, num_columns, num_channels)

# General Spatial Dropout rate
spatial_dropout_rate = 0.24

# Conv 1
model.add(Conv2D(filters=16, kernel_size=(3,3), input_shape=input_shape, activation='relu'))
model.add(BatchNormalization())
model.add(SpatialDropout2D(spatial_dropout_rate))

# Conv 2
model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
model.add(SpatialDropout2D(spatial_dropout_rate))
model.add(MaxPooling2D(pool_size=2))

# Conv 3
model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
model.add(SpatialDropout2D(spatial_dropout_rate))
model.add(MaxPooling2D(pool_size=2))

# Conv 4
model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
model.add(SpatialDropout2D(spatial_dropout_rate))
model.add(MaxPooling2D(pool_size=2))
          
# Conv 5
model.add(Conv2D(filters=256, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
model.add(SpatialDropout2D(spatial_dropout_rate))


# Reduces each h×w feature map to a single number by taking the average of all h,w values.
model.add(GlobalAveragePooling2D())

# Softmax output
model.add(Dense(num_labels, activation='softmax'))
# Out:
# W0731 01:19:11.599071 140012423436096 deprecation_wrapper.py:119] From /home/eduugr/miniconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0731 01:19:11.644628 140012423436096 deprecation_wrapper.py:119] From /home/eduugr/miniconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0731 01:19:11.825411 140012423436096 deprecation_wrapper.py:119] From /home/eduugr/miniconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0731 01:19:11.826296 140012423436096 deprecation_wrapper.py:119] From /home/eduugr/miniconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0731 01:19:13.022858 140012423436096 deprecation_wrapper.py:119] From /home/eduugr/miniconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0731 01:19:13.128342 140012423436096 deprecation.py:506] From /home/eduugr/miniconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0731 01:19:13.243233 140012423436096 deprecation_wrapper.py:119] From /home/eduugr/miniconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %% [markdown]
# #### Model optimizer and loss
#
# Using [ADAM](https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/) with default parameters for start from somewhere.
# Loss function is categorical cross-entropy as we are predicting between 10 classes.

# %%
adam = Adam(lr=1.5e-3, beta_1=0.99, beta_2=0.999)
model.compile(
    loss='categorical_crossentropy', 
    metrics=['accuracy'], 
    optimizer=adam)

# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(X_test, y_test_encoded, verbose=1)
accuracy = 100 * score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# W0731 01:19:38.343889 140012423436096 deprecation_wrapper.py:119] From /home/eduugr/miniconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 38, 172, 16)       160
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 38, 172, 16)       64
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 38, 172, 16)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 36, 170, 32)       4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 36, 170, 32)       128
# _________________________________________________________________
# spatial_dropout2d_2 (Spatial (None, 36, 170, 32)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 18, 85, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 83, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 83, 64)        256
# _________________________________________________________________
# spatial_dropout2d_3 (Spatial (None, 16, 83, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 41, 64)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 39, 128)        73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 6, 39, 128)        512
# _________________________________________________________________
# spatial_dropout2d_4 (Spatial (None, 6, 39, 128)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 19, 128)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1, 17, 256)        295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1, 17, 256)        1024
# _________________________________________________________________
# spatial_dropout2d_5 (Spatial (None, 1, 17, 256)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 396,874
# Trainable params: 395,882
# Non-trainable params: 992
# _________________________________________________________________
# 1746/1746 [==============================] - 6s 3ms/step
# Pre-training accuracy: 12.0275%

# %% [markdown]
# #### Training the model

# %%
num_epochs = 80
num_batch_size = 256
model_file = 'logscaled-v0.1.hdf5'
model_path = os.path.join(models_path, model_file)


# Save checkpoints
checkpointer = ModelCheckpoint(filepath=model_path, 
                               verbose=1, 
                               save_best_only=True)
start = datetime.now()
history = model.fit(X_train, 
                    y_train_encoded, 
                    batch_size=num_batch_size, 
                    epochs=num_epochs, 
                    validation_data=(X_test, y_test_encoded), 
                    callbacks=[checkpointer], 
                    verbose=1)

duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# W0731 01:20:48.602335 140012423436096 deprecation.py:323] From /home/eduugr/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 6986 samples, validate on 1746 samples
# Epoch 1/80
# 6986/6986 [==============================] - 41s 6ms/step - loss: 2.9621 - acc: 0.1036 - val_loss: 6.3407 - val_acc: 0.0395
#
# Epoch 00001: val_loss improved from inf to 6.34069, saving model to /mnt/disks/disk-1/projects/urban-audio-classifier/models/logscaled-v0.1.hdf5
# Epoch 2/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.5829 - acc: 0.1085 - val_loss: 3.9195 - val_acc: 0.1128
#
# Epoch 00002: val_loss improved from 6.34069 to 3.91948, saving model to /mnt/disks/disk-1/projects/urban-audio-classifier/models/logscaled-v0.1.hdf5
# Epoch 3/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.4741 - acc: 0.1128 - val_loss: 2.6472 - val_acc: 0.1186
#
# Epoch 00003: val_loss improved from 3.91948 to 2.64719, saving model to /mnt/disks/disk-1/projects/urban-audio-classifier/models/logscaled-v0.1.hdf5
# Epoch 4/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.4345 - acc: 0.1098 - val_loss: 2.4133 - val_acc: 0.1123
#
# Epoch 00004: val_loss improved from 2.64719 to 2.41331, saving model to /mnt/disks/disk-1/projects/urban-audio-classifier/models/logscaled-v0.1.hdf5
# Epoch 5/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.3870 - acc: 0.1148 - val_loss: 2.2848 - val_acc: 0.1123
#
# Epoch 00005: val_loss improved from 2.41331 to 2.28475, saving model to /mnt/disks/disk-1/projects/urban-audio-classifier/models/logscaled-v0.1.hdf5
# Epoch 6/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.3727 - acc: 0.1119 - val_loss: 2.2705 - val_acc: 0.1157
#
# Epoch 00006: val_loss improved from 2.28475 to 2.27052, saving model to /mnt/disks/disk-1/projects/urban-audio-classifier/models/logscaled-v0.1.hdf5
# Epoch 7/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.3608 - acc: 0.1162 - val_loss: 2.2623 - val_acc: 0.1128
#
# Epoch 00007: val_loss improved from 2.27052 to 2.26225, saving model to /mnt/disks/disk-1/projects/urban-audio-classifier/models/logscaled-v0.1.hdf5
# Epoch 8/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.3320 - acc: 0.1171 - val_loss: 2.2580 - val_acc: 0.1128
#
# Epoch 00008: val_loss improved from 2.26225 to 2.25804, saving model to /mnt/disks/disk-1/projects/urban-audio-classifier/models/logscaled-v0.1.hdf5
# Epoch 9/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.3284 - acc: 0.1109 - val_loss: 2.2576 - val_acc: 0.1128
#
# Epoch 00009: val_loss improved from 2.25804 to 2.25765, saving model to /mnt/disks/disk-1/projects/urban-audio-classifier/models/logscaled-v0.1.hdf5
# Epoch 10/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.3248 - acc: 0.1098 - val_loss: 2.2531 - val_acc: 0.1203
#
# Epoch 00010: val_loss improved from 2.25765 to 2.25306, saving model to /mnt/disks/disk-1/projects/urban-audio-classifier/models/logscaled-v0.1.hdf5
# Epoch 11/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.3149 - acc: 0.1114 - val_loss: 2.2564 - val_acc: 0.1123
#
# Epoch 00011: val_loss did not improve from 2.25306
# Epoch 12/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.3127 - acc: 0.1138 - val_loss: 2.2579 - val_acc: 0.1186
#
# Epoch 00012: val_loss did not improve from 2.25306
# Epoch 13/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.3091 - acc: 0.1124 - val_loss: 2.2587 - val_acc: 0.1203
#
# Epoch 00013: val_loss did not improve from 2.25306
# Epoch 14/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.3037 - acc: 0.1121 - val_loss: 2.2608 - val_acc: 0.1123
#
# Epoch 00014: val_loss did not improve from 2.25306
# Epoch 15/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2952 - acc: 0.1158 - val_loss: 2.2588 - val_acc: 0.1128
#
# Epoch 00015: val_loss did not improve from 2.25306
# Epoch 16/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2966 - acc: 0.1139 - val_loss: 2.2561 - val_acc: 0.1123
#
# Epoch 00016: val_loss did not improve from 2.25306
# Epoch 17/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2891 - acc: 0.1145 - val_loss: 2.2578 - val_acc: 0.1157
#
# Epoch 00017: val_loss did not improve from 2.25306
# Epoch 18/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2903 - acc: 0.1141 - val_loss: 2.2558 - val_acc: 0.1186
#
# Epoch 00018: val_loss did not improve from 2.25306
# Epoch 19/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2861 - acc: 0.1165 - val_loss: 2.2536 - val_acc: 0.1203
#
# Epoch 00019: val_loss did not improve from 2.25306
# Epoch 20/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2889 - acc: 0.1084 - val_loss: 2.2586 - val_acc: 0.1071
#
# Epoch 00020: val_loss did not improve from 2.25306
# Epoch 21/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2830 - acc: 0.1149 - val_loss: 2.2582 - val_acc: 0.1145
#
# Epoch 00021: val_loss did not improve from 2.25306
# Epoch 22/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2793 - acc: 0.1147 - val_loss: 2.2582 - val_acc: 0.1123
#
# Epoch 00022: val_loss did not improve from 2.25306
# Epoch 23/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2819 - acc: 0.1112 - val_loss: 2.2574 - val_acc: 0.1123
#
# Epoch 00023: val_loss did not improve from 2.25306
# Epoch 24/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2814 - acc: 0.1119 - val_loss: 2.2545 - val_acc: 0.1128
#
# Epoch 00024: val_loss did not improve from 2.25306
# Epoch 25/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2770 - acc: 0.1059 - val_loss: 2.2578 - val_acc: 0.1157
#
# Epoch 00025: val_loss did not improve from 2.25306
# Epoch 26/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2807 - acc: 0.1180 - val_loss: 2.2550 - val_acc: 0.1134
#
# Epoch 00026: val_loss did not improve from 2.25306
# Epoch 27/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2824 - acc: 0.1164 - val_loss: 2.2591 - val_acc: 0.1134
#
# Epoch 00027: val_loss did not improve from 2.25306
# Epoch 28/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2787 - acc: 0.1162 - val_loss: 2.2604 - val_acc: 0.1134
#
# Epoch 00028: val_loss did not improve from 2.25306
# Epoch 29/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2778 - acc: 0.1148 - val_loss: 2.2544 - val_acc: 0.1203
#
# Epoch 00029: val_loss did not improve from 2.25306
# Epoch 30/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2760 - acc: 0.1112 - val_loss: 2.2524 - val_acc: 0.1145
#
# Epoch 00030: val_loss improved from 2.25306 to 2.25238, saving model to /mnt/disks/disk-1/projects/urban-audio-classifier/models/logscaled-v0.1.hdf5
# Epoch 31/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2840 - acc: 0.1102 - val_loss: 2.2588 - val_acc: 0.1128
#
# Epoch 00031: val_loss did not improve from 2.25238
# Epoch 32/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2833 - acc: 0.1109 - val_loss: 2.2621 - val_acc: 0.1157
#
# Epoch 00032: val_loss did not improve from 2.25238
# Epoch 33/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2827 - acc: 0.1092 - val_loss: 2.2566 - val_acc: 0.1123
#
# Epoch 00033: val_loss did not improve from 2.25238
# Epoch 34/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2812 - acc: 0.1096 - val_loss: 2.2555 - val_acc: 0.1157
#
# Epoch 00034: val_loss did not improve from 2.25238
# Epoch 35/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2792 - acc: 0.1117 - val_loss: 2.2547 - val_acc: 0.1203
#
# Epoch 00035: val_loss did not improve from 2.25238
# Epoch 36/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2767 - acc: 0.1154 - val_loss: 2.2563 - val_acc: 0.1186
#
# Epoch 00036: val_loss did not improve from 2.25238
# Epoch 37/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2717 - acc: 0.1152 - val_loss: 2.2556 - val_acc: 0.1186
#
# Epoch 00037: val_loss did not improve from 2.25238
# Epoch 38/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2771 - acc: 0.1058 - val_loss: 2.2527 - val_acc: 0.1203
# Epoch 00038: val_loss did not improve from 2.25238
# Epoch 39/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2727 - acc: 0.1182 - val_loss: 2.2562 - val_acc: 0.1128
#
# Epoch 00039: val_loss did not improve from 2.25238
# Epoch 40/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2729 - acc: 0.1149 - val_loss: 2.2566 - val_acc: 0.1128
#
# Epoch 00040: val_loss did not improve from 2.25238
# Epoch 41/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2765 - acc: 0.1121 - val_loss: 2.2546 - val_acc: 0.1145
#
# Epoch 00041: val_loss did not improve from 2.25238
# Epoch 42/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2733 - acc: 0.1158 - val_loss: 2.2624 - val_acc: 0.1128
#
# Epoch 00042: val_loss did not improve from 2.25238
# Epoch 43/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2768 - acc: 0.1169 - val_loss: 2.2601 - val_acc: 0.1128
#
# Epoch 00043: val_loss did not improve from 2.25238
# Epoch 44/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2815 - acc: 0.1114 - val_loss: 2.2583 - val_acc: 0.1071
#
# Epoch 00044: val_loss did not improve from 2.25238
# Epoch 45/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2741 - acc: 0.1122 - val_loss: 2.2628 - val_acc: 0.1128
#
# Epoch 00045: val_loss did not improve from 2.25238
# Epoch 46/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2759 - acc: 0.1145 - val_loss: 2.2565 - val_acc: 0.1128
#
# Epoch 00046: val_loss did not improve from 2.25238
# Epoch 47/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2737 - acc: 0.1174 - val_loss: 2.2533 - val_acc: 0.1203
#
# Epoch 00047: val_loss did not improve from 2.25238
# Epoch 48/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2833 - acc: 0.1119 - val_loss: 2.2532 - val_acc: 0.1128
#
# Epoch 00048: val_loss did not improve from 2.25238
# Epoch 49/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2708 - acc: 0.1137 - val_loss: 2.2568 - val_acc: 0.1157
#
# Epoch 00049: val_loss did not improve from 2.25238
# Epoch 50/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2806 - acc: 0.1145 - val_loss: 2.2572 - val_acc: 0.1071
#
# Epoch 00050: val_loss did not improve from 2.25238
# Epoch 51/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2758 - acc: 0.1134 - val_loss: 2.2558 - val_acc: 0.1134
#
# Epoch 00051: val_loss did not improve from 2.25238
# Epoch 52/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2727 - acc: 0.1154 - val_loss: 2.2565 - val_acc: 0.1157
#
# Epoch 00052: val_loss did not improve from 2.25238
# Epoch 53/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2719 - acc: 0.1096 - val_loss: 2.2564 - val_acc: 0.1128
#
# Epoch 00053: val_loss did not improve from 2.25238
# Epoch 54/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2704 - acc: 0.1207 - val_loss: 2.2553 - val_acc: 0.1134
#
# Epoch 00054: val_loss did not improve from 2.25238
# Epoch 55/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2750 - acc: 0.1098 - val_loss: 2.2530 - val_acc: 0.1186
#
# Epoch 00055: val_loss did not improve from 2.25238
# Epoch 56/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2744 - acc: 0.1125 - val_loss: 2.2583 - val_acc: 0.1186
#
# Epoch 00056: val_loss did not improve from 2.25238
# Epoch 57/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2766 - acc: 0.1148 - val_loss: 2.2565 - val_acc: 0.1186
#
# Epoch 00057: val_loss did not improve from 2.25238
# Epoch 58/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2745 - acc: 0.1111 - val_loss: 2.2564 - val_acc: 0.1123
#
# Epoch 00058: val_loss did not improve from 2.25238
# Epoch 59/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2706 - acc: 0.1202 - val_loss: 2.2579 - val_acc: 0.1145
#
# Epoch 00059: val_loss did not improve from 2.25238
# Epoch 60/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2744 - acc: 0.1099 - val_loss: 2.2564 - val_acc: 0.1145
#
# Epoch 00060: val_loss did not improve from 2.25238
# Epoch 61/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2730 - acc: 0.1111 - val_loss: 2.2540 - val_acc: 0.1134
#
# Epoch 00061: val_loss did not improve from 2.25238
# Epoch 62/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2723 - acc: 0.1134 - val_loss: 2.2567 - val_acc: 0.1128
#
# Epoch 00062: val_loss did not improve from 2.25238
# Epoch 63/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2751 - acc: 0.1065 - val_loss: 2.2548 - val_acc: 0.1134
#
# Epoch 00063: val_loss did not improve from 2.25238
# Epoch 64/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2727 - acc: 0.1135 - val_loss: 2.2544 - val_acc: 0.1123
#
# Epoch 00064: val_loss did not improve from 2.25238
# Epoch 65/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2745 - acc: 0.1161 - val_loss: 2.2542 - val_acc: 0.1203
#
# Epoch 00065: val_loss did not improve from 2.25238
# Epoch 66/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2697 - acc: 0.1174 - val_loss: 2.2547 - val_acc: 0.1123
#
# Epoch 00066: val_loss did not improve from 2.25238
# Epoch 67/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2729 - acc: 0.1108 - val_loss: 2.2539 - val_acc: 0.1145
#
# Epoch 00067: val_loss did not improve from 2.25238
# Epoch 68/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2729 - acc: 0.1172 - val_loss: 2.2546 - val_acc: 0.1134
#
# Epoch 00068: val_loss did not improve from 2.25238
# Epoch 69/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2756 - acc: 0.1106 - val_loss: 2.2592 - val_acc: 0.1134
#
# Epoch 00069: val_loss did not improve from 2.25238
# Epoch 70/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2722 - acc: 0.1098 - val_loss: 2.2564 - val_acc: 0.1186
#
# Epoch 00070: val_loss did not improve from 2.25238
# Epoch 71/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2742 - acc: 0.1167 - val_loss: 2.2539 - val_acc: 0.1134
#
# Epoch 00071: val_loss did not improve from 2.25238
# Epoch 72/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2731 - acc: 0.1102 - val_loss: 2.2545 - val_acc: 0.1123
#
# Epoch 00072: val_loss did not improve from 2.25238
# Epoch 73/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2702 - acc: 0.1177 - val_loss: 2.2566 - val_acc: 0.1123
#
# Epoch 00073: val_loss did not improve from 2.25238
# Epoch 74/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2723 - acc: 0.1139 - val_loss: 2.2544 - val_acc: 0.1123
#
# Epoch 00074: val_loss did not improve from 2.25238
# Epoch 75/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2748 - acc: 0.1157 - val_loss: 2.2542 - val_acc: 0.1128
#
# Epoch 00075: val_loss did not improve from 2.25238
# Epoch 76/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2716 - acc: 0.1088 - val_loss: 2.2548 - val_acc: 0.1128
#
# Epoch 00076: val_loss did not improve from 2.25238
# Epoch 77/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2697 - acc: 0.1164 - val_loss: 2.2551 - val_acc: 0.1145
#
# Epoch 00077: val_loss did not improve from 2.25238
# Epoch 78/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2682 - acc: 0.1184 - val_loss: 2.2543 - val_acc: 0.1145
#
# Epoch 00078: val_loss did not improve from 2.25238
# Epoch 79/80
# 6986/6986 [==============================] - 35s 5ms/step - loss: 2.2669 - acc: 0.1134 - val_loss: 2.2544 - val_acc: 0.1157
#
# Epoch 00079: val_loss did not improve from 2.25238
# Epoch 80/80
# 6986/6986 [==============================] - 36s 5ms/step - loss: 2.2694 - acc: 0.1139 - val_loss: 2.2560 - val_acc: 0.1145
#
# Epoch 00080: val_loss did not improve from 2.25238
# Training completed in time:  0:47:34.094396

# %% [markdown]
# ### Optional: load previously saved model data

# %%
# Optionally load a previously saved model
from keras import models

# Load a full model
model = models.load_model(model_path)

# %% [markdown]
# #### Model evaluation

# %%
# Score on training data
score = model.evaluate(X_train, y_train_encoded, verbose=0)
print("Training Accuracy: ", score[1])

# Score on test data
score = model.evaluate(X_test, y_test_encoded, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.1145147437753938
# Testing Accuracy:  0.11454753723648406
